# %% [markdown]
# # 3. Image to tf.Data conversion and .npy storage

# %%
import logging
import logging.config
from os import listdir
from os.path import isfile, join
from Eyeonic_image_resizer import ImageResizer

# This default job to 224px images, will shrink the dataset from 1,439,776,768 bytes
# to 116,813,824 bytes 91.8% size reduction


def process_all_images():
    files = [f for f in listdir(source_folder) if isfile(join(source_folder, f))]
    for file in files:
        logger.debug('Processing image: ' + file)
        ImageResizer(image_width, quality, source_folder, destination_folder, file, keep_aspect_ratio).run()


if __name__ == '__main__':
    # Set the base width of the image to 200 pixels
    image_width = 224
    keep_aspect_ratio = False
    # set the quality of the resultant jpeg to 100%
    quality = 100
    source_folder = r'Eyeonic_Training_Dataset_cropped'
    destination_folder = r'Eyeonic_Training_Dataset_treated' + '_' + str(image_width)
    # create logger
    logging.config.fileConfig('logging.conf')
    logger = logging.getLogger('Eyeonic')
    process_all_images()
# Out:
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Processing image: 0_left.jpg]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Processing image: 0_right.jpg]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Processing image: 1005_left.jpg]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Processing image: 1005_right.jpg]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:37] - [Eyeonic] - [DEBUG] - [Processing image: 1006_left.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 1006_right.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 1008_left.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 1008_right.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 100_left.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 100_right.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 1010_left.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 1010_right.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 1011_left.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 1011_right.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 1012_left.jpg]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:38] - [Eyeonic] - [DEBUG] - [Processing image: 1012_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1013_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1013_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1014_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1014_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1015_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1015_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1016_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1016_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1017_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1017_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1018_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1018_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1019_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1019_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 101_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 101_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1020_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1020_right.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1021_left.jpg]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:39] - [Eyeonic] - [DEBUG] - [Processing image: 1021_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1022_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1022_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1023_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1023_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1024_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1024_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1028_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1028_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 102_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 102_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1031_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1031_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1032_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1032_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1033_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1033_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1034_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1034_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1035_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1035_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1036_left.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1036_right.jpg]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:40] - [Eyeonic] - [DEBUG] - [Processing image: 1038_left.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1038_right.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1039_left.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1039_right.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 103_left.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 103_right.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1040_left.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1040_right.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1041_left.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1041_right.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1043_left.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1043_right.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1045_left.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1045_right.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1046_left.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1046_right.jpg]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:41] - [Eyeonic] - [DEBUG] - [Processing image: 1048_left.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1048_right.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 104_left.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 104_right.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1050_left.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1050_right.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1052_left.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1052_right.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1053_left.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1053_right.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1054_left.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1054_right.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1056_left.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1056_right.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1058_left.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1058_right.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1059_left.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image: 1059_right.jpg]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:19:42] - [Eyeonic] - [DEBUG] - [Processing image:

# [2024-Mar-17 03:28:25] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:25] - [Eyeonic] - [DEBUG] - [Processing image: 990_right.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 991_left.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 991_right.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 992_left.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 992_right.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 993_left.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 993_right.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 994_left.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 994_right.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 996_left.jpg]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:26] - [Eyeonic] - [DEBUG] - [Processing image: 996_right.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 997_left.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 997_right.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 998_left.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 998_right.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 999_left.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 999_right.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 99_left.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 99_right.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 9_left.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Processing image: 9_right.jpg]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Right eye image found. Flipping it]
# [2024-Mar-17 03:28:27] - [Eyeonic] - [DEBUG] - [Image saved]

# %%
from absl import app
import logging
import logging.config
import time
import csv
import cv2
import os
import numpy as np
import glob


class NumpyDataGenerator:
    def __init__(self, training_path, testing_path, csv_path, csv_testing_path, augmented_path, csv_augmented_file):
        self.training_path = training_path
        self.testing_path = testing_path
        self.csv_path = csv_path
        self.csv_testing_path = csv_testing_path
        self.logger = logging.getLogger('Eyeonic')
        self.total_records_training = 0
        self.total_records_testing = 0
        self.csv_augmented_path = csv_augmented_file
        self.augmented_path = augmented_path

    def npy_training_files(self, file_name_training, file_name_training_labels):
        training = []
        training_labels = []

        self.logger.debug("Opening CSV file")
        with open(self.csv_path) as csvDataFile:
            csv_reader = csv.reader(csvDataFile)
            self.total_records_training = 0
            for row in csv_reader:
                column_id = row[0]
                normal = row[1]
                diabetes = row[2]
                glaucoma = row[3]
                cataract = row[4]
                amd = row[5]
                hypertension = row[6]
                myopia = row[7]
                others = row[8]
                # just discard the first row
                if column_id != "ID":
                    self.logger.debug("Processing image: " + column_id)
                    # load first the image from the folder
                    eye_image = os.path.join(self.training_path, column_id)
                    image = cv2.imread(eye_image)
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                    training.append(image)
                    training_labels.append([normal, diabetes, glaucoma, cataract, amd, hypertension, myopia, others])
                    self.total_records_training = self.total_records_training + 1

        training = np.array(training, dtype='uint8')
        training_labels = np.array(training_labels, dtype='uint8')
        # convert (number of images x height x width x number of channels) to (number of images x (height * width *3))
        # for example (6069 * 28 * 28 * 3)-> (6069 x 2352) (14,274,288)
        training = np.reshape(training, [training.shape[0], training.shape[1], training.shape[2], training.shape[3]])

        # save numpy array as .npy formats
        np.save(file_name_training, training)
        self.logger.debug("Saving NPY File: " + file_name_training)
        np.save(file_name_training_labels, training_labels)
        self.logger.debug("Saving NPY File: " + file_name_training_labels)
        self.logger.debug("Closing CSV file")

    def npy_testing_files(self, file_name_testing, file_name_testing_labels):
        testing = []
        testing_labels = []

        self.logger.debug("Opening CSV file")
        with open(self.csv_testing_path) as csvDataFile:
            csv_reader = csv.reader(csvDataFile)
            self.total_records_testing = 0
            for row in csv_reader:
                column_id = row[0]
                normal = row[1]
                diabetes = row[2]
                glaucoma = row[3]
                cataract = row[4]
                amd = row[5]
                hypertension = row[6]
                myopia = row[7]
                others = row[8]
                # just discard the first row
                if column_id != "ID":
                    self.logger.debug("Processing image: " + column_id + "_left.jpg")
                    # load first the image from the folder
                    eye_image = os.path.join(self.testing_path, column_id + "_left.jpg")
                    image = cv2.imread(eye_image)
                    if image is None:
                        logger.error(f"Failed to load image: {eye_image}")
                        continue  # Skip to the next iteration of the loop
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                    testing.append(image)
                    testing_labels.append([normal, diabetes, glaucoma, cataract, amd, hypertension, myopia, others])
                    self.total_records_testing = self.total_records_testing + 1

                    self.logger.debug("Processing image: " + column_id + "_right.jpg")
                    eye_image = os.path.join(self.testing_path, column_id + "_right.jpg")
                    image = cv2.imread(eye_image)
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                    testing.append(image)
                    testing_labels.append([normal, diabetes, glaucoma, cataract, amd, hypertension, myopia, others])
                    self.total_records_testing = self.total_records_testing + 1

        testing = np.array(testing, dtype='uint8')
        training_labels = np.array(testing_labels, dtype='uint8')
        # convert (number of images x height x width x number of channels) to (number of images x (height * width *3))
        # for example (6069 * 28 * 28 * 3)-> (6069 x 2352) (14,274,288)
        testing = np.reshape(testing, [testing.shape[0], testing.shape[1], testing.shape[2], testing.shape[3]])

        # save numpy array as .npy formats
        np.save(file_name_testing, testing)
        self.logger.debug("Saving NPY File: " + file_name_testing)
        np.save(file_name_testing_labels, training_labels)
        self.logger.debug("Saving NPY File: " + file_name_testing_labels)
        self.logger.debug("Closing CSV file")

    def npy_training_files_split(self, split_number, file_name_training, file_name_training_labels, file_name_testing,
                                 file_name_testing_labels):
        training = []
        training_labels = []
        testing = []
        testing_labels = []

        self.logger.debug("Opening CSV file")
        count = 0
        with open(self.csv_path) as csvDataFile:
            csv_reader = csv.reader(csvDataFile)
            self.total_records_training = 0
            self.total_records_testing = 0
            for row in csv_reader:
                column_id = row[0]
                label = row[1]
                # just discard the first row
                if column_id != "ID":
                    self.logger.debug("Processing image: " + column_id)
                    # load first the image from the folder
                    eye_image = os.path.join(self.training_path, column_id)
                    image = cv2.imread(eye_image)
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                    if count < split_number:
                        testing.append(image)
                        testing_labels.append(label)
                        self.total_records_testing = self.total_records_testing + 1
                    else:
                        training.append(image)
                        training_labels.append(label)
                        self.total_records_training = self.total_records_training + 1
                    count = count + 1

        testing = np.array(testing, dtype='uint8')
        testing_labels = np.array(testing_labels, dtype='uint8')
        testing = np.reshape(testing, [testing.shape[0], testing.shape[1], testing.shape[2], testing.shape[3]])

        # save numpy array as .npy formats
        np.save(file_name_testing, testing)
        np.save(file_name_testing_labels, testing_labels)

        training = np.array(training, dtype='uint8')
        training_labels = np.array(training_labels, dtype='uint8')
        # convert (number of images x height x width x number of channels) to (number of images x (height * width *3))
        # for example (6069 * 28 * 28 * 3)-> (6069 x 2352) (14,274,288)
        training = np.reshape(training, [training.shape[0], training.shape[1], training.shape[2], training.shape[3]])

        # save numpy array as .npy formats
        np.save(file_name_training, training)
        self.logger.debug("Saving NPY File: " + file_name_training)
        np.save(file_name_training_labels, training_labels)
        self.logger.debug("Saving NPY File: " + file_name_training_labels)
        self.logger.debug("Closing CSV file")

    def is_sickness(self, row, sickness):
        switcher = {
            "normal": row[1] == '1' and row[2] == '0' and row[3] == '0' and row[4] == '0' and row[5] == '0' and row[
                6] == '0' and row[7] == '0' and row[8] == '0',
            "diabetes": row[1] == '0' and row[2] == '1' and row[3] == '0' and row[4] == '0' and row[5] == '0' and row[
                6] == '0' and row[7] == '0' and row[8] == '0',
            "glaucoma": row[1] == '0' and row[2] == '0' and row[3] == '1' and row[4] == '0' and row[5] == '0' and row[
                6] == '0' and row[7] == '0' and row[8] == '0',
            "cataract": row[1] == '0' and row[2] == '0' and row[3] == '0' and row[4] == '1' and row[5] == '0' and row[
                6] == '0' and row[7] == '0' and row[8] == '0',
            "amd": row[1] == '0' and row[2] == '0' and row[3] == '0' and row[4] == '0' and row[5] == '1' and row[
                6] == '0' and row[7] == '0' and row[8] == '0',
            "hypertension": row[1] == '0' and row[2] == '0' and row[3] == '0' and row[4] == '0' and row[5] == '0' and
                            row[6] == '1' and row[7] == '0' and row[8] == '0',
            "myopia": row[1] == '0' and row[2] == '0' and row[3] == '0' and row[4] == '0' and row[5] == '0' and row[
                6] == '0' and row[7] == '1' and row[8] == '0',
            "others": row[1] == '0' and row[2] == '0' and row[3] == '0' and row[4] == '0' and row[5] == '0' and row[
                6] == '0' and row[7] == '0' and row[8] == '1'
        }
        return switcher.get(sickness, False)

    def npy_training_files_split_all(self, split_number, file_name_training, file_name_training_labels,
                                     file_name_testing,
                                     file_name_testing_labels, include_augmented):
        split_factor = 10820
        training = []
        training_labels = []
        training_2 = []
        training_labels_2 = []
        testing = []
        testing_labels = []
        images_used = []
        count_images = 0

        class_names = ['normal', 'diabetes', 'glaucoma', 'cataract', 'amd',
                       'hypertension', 'myopia', 'others']

        self.logger.debug("Opening CSV file")

        class_count = {'normal': 0, 'diabetes': 0, 'glaucoma': 0, 'cataract': 0, 'amd': 0, 'hypertension': 0,
                       'myopia': 0, 'others': 0}
        split_pocket = split_number / 8
        with open(self.csv_path) as csvDataFile:
            csv_reader = csv.reader(csvDataFile)
            self.total_records_training = 0
            self.total_records_testing = 0
            for row in csv_reader:
                column_id = row[0]
                normal = row[1]
                diabetes = row[2]
                glaucoma = row[3]
                cataract = row[4]
                amd = row[5]
                hypertension = row[6]
                myopia = row[7]
                others = row[8]
                # just discard the first row
                if column_id != "ID":
                    self.logger.debug("Processing image: " + column_id)
                    # load first the image from the folder
                    eye_image = os.path.join(self.training_path, column_id)
                    image = cv2.imread(eye_image)
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                    found = False
                    for sickness in class_names:
                        if self.is_sickness(row, sickness) and class_count[sickness] < split_pocket:
                            testing.append(image)
                            images_used.append(row[0] + ',' + sickness + ',' + str(class_count[sickness]))
                            testing_labels.append([normal, diabetes, glaucoma, cataract, amd, hypertension, myopia, others])
                            self.total_records_testing = self.total_records_testing + 1
                            class_count[sickness] = class_count[sickness] + 1
                            found = True
                            logger.debug('found ' + sickness + ' ' + str(class_count[sickness]))

                    if not found:
                        training.append(image)
                        training_labels.append([normal, diabetes, glaucoma, cataract, amd, hypertension, myopia, others])
                        self.total_records_training = self.total_records_training + 1
                        count_images = count_images + 1

        if include_augmented:
            with open(self.csv_augmented_path) as csvDataFile:
                csv_reader = csv.reader(csvDataFile)
                for row in csv_reader:
                    column_id = row[0]
                    normal = row[1]
                    diabetes = row[2]
                    glaucoma = row[3]
                    cataract = row[4]
                    amd = row[5]
                    hypertension = row[6]
                    myopia = row[7]
                    others = row[8]
                    # just discard the first row
                    if column_id != "ID":
                        self.logger.debug("Processing image: " + column_id)
                        # load first the image from the folder
                        eye_image = os.path.join(self.augmented_path, column_id)
                        image = cv2.imread(eye_image)
                        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                        if count_images >= split_factor:
                            training_2.append(image)
                            training_labels_2.append([normal, diabetes, glaucoma, cataract, amd, hypertension, myopia, others])
                        else:
                            training.append(image)
                            training_labels.append([normal, diabetes, glaucoma, cataract, amd, hypertension, myopia, others])
                        self.total_records_training = self.total_records_training + 1
                        count_images = count_images + 1

        testing = np.array(testing, dtype='uint8')
        testing_labels = np.array(testing_labels, dtype='uint8')
        testing = np.reshape(testing, [testing.shape[0], testing.shape[1], testing.shape[2], testing.shape[3]])

        # save numpy array as .npy formats
        np.save(file_name_testing, testing)
        np.save(file_name_testing_labels, testing_labels)

        training = np.array(training, dtype='uint8')
        training_labels = np.array(training_labels, dtype='uint8')
        # convert (number of images x height x width x number of channels) to (number of images x (height * width *3))
        # for example (6069 * 28 * 28 * 3)-> (6069 x 2352) (14,274,288)
        training = np.reshape(training, [training.shape[0], training.shape[1], training.shape[2], training.shape[3]])

        # convert (number of images x height x width x number of channels) to (number of images x (height * width *3))
        # for example (6069 * 28 * 28 * 3)-> (6069 x 2352) (14,274,288)
        if include_augmented:
            training_2 = np.array(training_2, dtype='uint8')
            training_labels_2 = np.array(training_labels_2, dtype='uint8')
            training_2 = np.reshape(training_2, [training_2.shape[0], training_2.shape[1], training_2.shape[2], training_2.shape[3]])

        self.logger.debug(testing.shape)
        self.logger.debug(testing_labels.shape)
        self.logger.debug(training.shape)
        self.logger.debug(training_labels.shape)
        if include_augmented:
            self.logger.debug(training_2.shape)
            self.logger.debug(training_labels_2.shape)

        # save numpy array as .npy formats
        np.save(file_name_training + '_1', training)
        np.save(file_name_training_labels + '_1', training_labels)
        if include_augmented:
            np.save(file_name_training + '_2', training_2)
            np.save(file_name_training_labels + '_2', training_labels_2)
        self.logger.debug("Closing CSV file")
        for sickness in class_names:
            self.logger.debug('found ' + sickness + ' ' + str(class_count[sickness]))
        csv_writer = csv.writer(open("files_used.csv", 'w', newline=''))
        for item in images_used:
            self.logger.debug(item)
            entries = item.split(",")
            csv_writer.writerow(entries)


# def main(argv):
def main():
    start = time.time()
    image_width = 224
    training_path = r'Eyeonic_Training_Dataset_treated' + '_' + str(image_width)
    testing_path = r'Eyeonic_Testing_Images_treated' + '_' + str(image_width)
    augmented_path = r'Eyeonic_Training_Dataset_augmented' + '_' + str(image_width)
    csv_file = r'ground_truth/Eyeonic_labels.csv'
    csv_augmented_file = r'ground_truth/Eyeonic_augmented.csv'
    training_file = r'ground_truth/testing_default_value.csv'
    logger.debug('Generating npy files')
    generator = NumpyDataGenerator(training_path, testing_path, csv_file, training_file, augmented_path,
                                   csv_augmented_file)

    # Generate testing file
    generator.npy_testing_files('Eyeonic_testing_challenge' + '_' + str(image_width), 'Eyeonic_testing_labels_challenge' + '_' + str(image_width))
    # Generate training file
    generator.npy_training_files('Eyeonic_training', 'Eyeonic_training_labels')
    generator.npy_training_files_split(1000,'Eyeonic_training','Eyeonic_training_labels', 'Eyeonic_testing', 'Eyeonic_testing_labels')
    generator.npy_training_files_split_all(400,'Eyeonic_training' + '_' + str(image_width),
                                           'Eyeonic_training_labels' + '_' + str(image_width),
                                           'Eyeonic_testing' + '_' + str(image_width),
                                           'Eyeonic_testing_labels' + '_' + str(image_width),
                                           True)
    end = time.time()
    logger.debug('Training Records ' + str(generator.total_records_training))
    logger.debug('Testing Records ' + str(generator.total_records_testing))
    logger.debug('All Done in ' + str(end - start) + ' seconds')

# %%
# create logger
logging.config.fileConfig('logging.conf')
logger = logging.getLogger('Eyeonic')

# %%
# app.run(main)
main()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # app.run(main)
# ----> 2 main()
#
# Cell In[20], line 346, in main()
#     344 generator.npy_training_files('Eyeonic_training', 'Eyeonic_training_labels')
#     345 generator.npy_training_files_split(1000,'Eyeonic_training','Eyeonic_training_labels', 'Eyeonic_testing', 'Eyeonic_testing_labels')
# --> 346 generator.npy_training_files_split_all(400,'Eyeonic_training' + '_' + str(image_width),
#     347                                        'Eyeonic_training_labels' + '_' + str(image_width),
#     348                                        'Eyeonic_testing' + '_' + str(image_width),
#     349                                        'Eyeonic_testing_labels' + '_' + str(image_width),
#     350                                        True)
#     351 end = time.time()
#     352 logger.debug('Training Records ' + str(generator.total_records_training))
#
# Cell In[20], line 301, in NumpyDataGenerator.npy_training_files_split_all(self, split_number, file_name_training, file_name_training_labels, file_name_testing, file_name_testing_labels, include_augmented)
#     299     training_2 = np.array(training_2, dtype='uint8')
#     300     training_labels_2 = np.array(training_labels_2, dtype='uint8')
# --> 301     training_2 = np.reshape(training_2, [training_2.shape[0], training_2.shape[1], training_2.shape[2], training_2.shape[3]])
#     303 self.logger.debug(testing.shape)
#     304 self.logger.debug(testing_labels.shape)
#
# IndexError: tuple index out of range

# %%
#this file has complete code for conversion of images from tensorflow to npy
